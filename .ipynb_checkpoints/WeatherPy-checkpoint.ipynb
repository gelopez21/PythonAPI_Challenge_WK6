# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#See Analysis At The End#

#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as stats
import os

#Import API key
from api_keys import weather_api_key

#Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Output File (CSV)
output_data_file = "output_data/cities.csv" 

#Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#List cities
lat_lngs = []
cities = []

#Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

#Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

#Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
setcounter=1
recordcounter=1
cityid=0

url = "http://api.openweathermap.org/data/2.5/weather"
units = "imperial"

print("Beginning Data Retrieval \n ------------------")

citydatalist=[]

for city in cities:
    print(f"Processing Record {recordcounter} of Set {setcounter} | {city}")
    try:
        response = requests.get(url,params={"appid":weather_api_key,"units":units,"q":city}).json()
        citydatalist.append({
            "City_ID":cityid,
            "City":city,
            "Cloudiness":response["clouds"]["all"],
            "Country":response["sys"]["country"],
            "Date":response["dt"],
            "Humidity":response["main"]["humidity"],
            "Lat":response["coord"]["lat"],
            "Lng":response["coord"]["lon"],
            "Max Temp":response["main"]["temp_max"],
            "Wind Speed":response["wind"]["speed"]
        })
    except:
        print("City not found. Skipping...")
    if recordcounter==50:
        recordcounter=1
        setcounter=setcounter+1
    else:
        recordcounter=recordcounter+1
    cityid=cityid+1

print("------------------\nData Retrieval Complete\n------------------")
# Out:
# Beginning Data Retrieval
#  ------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | hovd
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | elizabeth city
# Processing Record 7 of Set 1 | ligayan
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | axim
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | hami
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | plettenberg bay
# Processing Record 22 of Set 1 | tome-acu
# City not found. Skipping...
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | lodja
# Processing Record 29 of Set 1 | nantucket
# Processing Record 30 of Set 1 | huarmey
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | hobyo
# Processing Record 33 of Set 1 | la ronge
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | vestmanna
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | sorland
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | lasa
# Processing Record 41 of Set 1 | bathsheba
# Processing Record 42 of Set 1 | isangel
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | nakasongola
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | moose factory
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | kharitonovo
# Processing Record 15 of Set 5 | tete
# Processing Record 16 of Set 5 | marabba
# Processing Record 17 of Set 5 | chernyshevskiy
# Processing Record 18 of Set 5 | eyl
# Processing Record 19 of Set 5 | zemio
# Processing Record 20 of Set 5 | leua
# Processing Record 21 of Set 5 | ulladulla
# Processing Record 22 of Set 5 | basco
# Processing Record 23 of Set 5 | maraba
# Processing Record 24 of Set 5 | avera
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 5 | bonavista
# Processing Record 29 of Set 5 | vostok
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | samana
# Processing Record 33 of Set 5 | port alfred
# Processing Record 34 of Set 5 | roald
# Processing Record 35 of Set 5 | washougal
# Processing Record 36 of Set 5 | ambilobe
# Processing Record 37 of Set 5 | arlit
# Processing Record 38 of Set 5 | praia da vitoria
# Processing Record 39 of Set 5 | barrow
# Processing Record 40 of Set 5 | umm jarr
# City not found. Skipping...
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | preobrazheniye
# Processing Record 43 of Set 5 | komsomolskiy
# Processing Record 44 of Set 5 | ust-nera
# Processing Record 45 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | ancud
# Processing Record 48 of Set 5 | gushikawa
# Processing Record 49 of Set 5 | highland springs
# Processing Record 50 of Set 5 | ginebra
# Processing Record 1 of Set 6 | kokopo
# Processing Record 2 of Set 6 | kloulklubed
# Processing Record 3 of Set 6 | barhi
# Processing Record 4 of Set 6 | nadym
# Processing Record 5 of Set 6 | tumpat
# Processing Record 6 of Set 6 | tomatlan
# Processing Record 7 of Set 6 | bambous virieux
# Processing Record 8 of Set 6 | mbaiki
# Processing Record 9 of Set 6 | saint george
# Processing Record 10 of Set 6 | soe
# Processing Record 11 of Set 6 | nanpara
# Processing Record 12 of Set 6 | montmagny
# Processing Record 13 of Set 6 | belmonte
# Processing Record 14 of Set 6 | los llanos de aridane
# Processing Record 15 of Set 6 | mosetse
# Processing Record 16 of Set 6 | athabasca
# Processing Record 17 of Set 6 | flinders
# Processing Record 18 of Set 6 | hearst
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | pisco
# Processing Record 21 of Set 6 | iskateley
# Processing Record 22 of Set 6 | tiarei
# Processing Record 23 of Set 6 | ostrovnoy
# Processing Record 24 of Set 6 | bitlis
# Processing Record 25 of Set 6 | tanete
# Processing Record 26 of Set 6 | faya
# Processing Record 27 of Set 6 | nalut
# Processing Record 28 of Set 6 | vila
# Processing Record 29 of Set 6 | blackwater
# Processing Record 30 of Set 6 | rach gia
# Processing Record 31 of Set 6 | port augusta
# Processing Record 32 of Set 6 | comodoro rivadavia
# Processing Record 33 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 6 | tongren
# Processing Record 35 of Set 6 | san patricio
# Processing Record 36 of Set 6 | yaring
# Processing Record 37 of Set 6 | ponta delgada
# Processing Record 38 of Set 6 | tabuk
# Processing Record 39 of Set 6 | nanortalik
# Processing Record 40 of Set 6 | sucila
# Processing Record 41 of Set 6 | grindavik
# Processing Record 42 of Set 6 | mitu
# Processing Record 43 of Set 6 | oranjestad
# Processing Record 44 of Set 6 | koutiala
# Processing Record 45 of Set 6 | ivdel
# Processing Record 46 of Set 6 | kotli loharan
# Processing Record 47 of Set 6 | mayumba
# Processing Record 48 of Set 6 | severnyy
# Processing Record 49 of Set 6 | sept-iles
# Processing Record 50 of Set 6 | ankpa
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | rio gallegos
# Processing Record 3 of Set 7 | chapais
# Processing Record 4 of Set 7 | upington
# Processing Record 5 of Set 7 | kingisepp
# Processing Record 6 of Set 7 | bertoua
# Processing Record 7 of Set 7 | kamen-na-obi
# Processing Record 8 of Set 7 | butaritari
# Processing Record 9 of Set 7 | loa janan
# Processing Record 10 of Set 7 | saint-pierre
# Processing Record 11 of Set 7 | bubaque
# Processing Record 12 of Set 7 | vao
# Processing Record 13 of Set 7 | clyde river
# Processing Record 14 of Set 7 | yelizovo
# Processing Record 15 of Set 7 | ahuimanu
# Processing Record 16 of Set 7 | biak
# Processing Record 17 of Set 7 | buala
# Processing Record 18 of Set 7 | kipen
# Processing Record 19 of Set 7 | minab
# Processing Record 20 of Set 7 | katsuura
# Processing Record 21 of Set 7 | sola
# Processing Record 22 of Set 7 | jasper
# Processing Record 23 of Set 7 | general roca
# Processing Record 24 of Set 7 | mercedes
# Processing Record 25 of Set 7 | lanzhou
# Processing Record 26 of Set 7 | kaputa
# Processing Record 27 of Set 7 | cherskiy
# Processing Record 28 of Set 7 | gazojak
# Processing Record 29 of Set 7 | mogadishu
# Processing Record 30 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 7 | honningsvag
# Processing Record 32 of Set 7 | ukmerge
# Processing Record 33 of Set 7 | kosai
# Processing Record 34 of Set 7 | namibe
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | san lorenzo
# Processing Record 37 of Set 7 | ilulissat
# Processing Record 38 of Set 7 | samarai
# Processing Record 39 of Set 7 | san quintin
# Processing Record 40 of Set 7 | roebourne
# Processing Record 41 of Set 7 | itarema
# Processing Record 42 of Set 7 | sompeta
# Processing Record 43 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 7 | jiangyan
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | simao
# Processing Record 47 of Set 7 | russell
# Processing Record 48 of Set 7 | puerto del rosario
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | venice
# Processing Record 1 of Set 8 | arraial do cabo
# Processing Record 2 of Set 8 | georgetown
# Processing Record 3 of Set 8 | shubarkuduk
# Processing Record 4 of Set 8 | lar gerd
# City not found. Skipping...
# Processing Record 5 of Set 8 | yumen
# Processing Record 6 of Set 8 | severo-kurilsk
# Processing Record 7 of Set 8 | port elizabeth
# Processing Record 8 of Set 8 | bandarbeyla
# Processing Record 9 of Set 8 | caracollo
# Processing Record 10 of Set 8 | hokitika
# Processing Record 11 of Set 8 | williams lake
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | zeya
# Processing Record 14 of Set 8 | floro
# Processing Record 15 of Set 8 | olinda
# Processing Record 16 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set
of Set 9 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 9 | kieta
# Processing Record 42 of Set 9 | aswan
# Processing Record 43 of Set 9 | montlucon
# Processing Record 44 of Set 9 | atyrau
# Processing Record 45 of Set 9 | shimanovsk
# Processing Record 46 of Set 9 | kiama
# Processing Record 47 of Set 9 | arriana
# Processing Record 48 of Set 9 | alyangula
# Processing Record 49 of Set 9 | northam
# Processing Record 50 of Set 9 | byron bay
# Processing Record 1 of Set 10 | vallenar
# Processing Record 2 of Set 10 | pincher creek
# Processing Record 3 of Set 10 | ji-parana
# City not found. Skipping...
# Processing Record 4 of Set 10 | halmstad
# Processing Record 5 of Set 10 | rocha
# Processing Record 6 of Set 10 | guaraniacu
# Processing Record 7 of Set 10 | sibut
# Processing Record 8 of Set 10 | novo aripuana
# Processing Record 9 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 10 | kenora
# Processing Record 12 of Set 10 | tiznit
# Processing Record 13 of Set 10 | xacmaz
# Processing Record 14 of Set 10 | christchurch
# Processing Record 15 of Set 10 | faanui
# Processing Record 16 of Set 10 | nara
# Processing Record 17 of Set 10 | harper
# Processing Record 18 of Set 10 | nicoya
# Processing Record 19 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 10 | ojinaga
# Processing Record 21 of Set 10 | doha
# Processing Record 22 of Set 10 | kamaishi
# Processing Record 23 of Set 10 | teya
# Processing Record 24 of Set 10 | alekseyevsk
# Processing Record 25 of Set 10 | ust-kut
# Processing Record 26 of Set 10 | marsh harbour
# Processing Record 27 of Set 10 | canico
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | dicabisagan
# Processing Record 30 of Set 10 | juneau
# Processing Record 31 of Set 10 | mugur-aksy
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | nageshwari
# Processing Record 34 of Set 10 | rio de janeiro
# Processing Record 35 of Set 10 | mehamn
# Processing Record 36 of Set 10 | elat
# Processing Record 37 of Set 10 | balkhash
# Processing Record 38 of Set 10 | kharp
# Processing Record 39 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 10 | tevriz
# Processing Record 41 of Set 10 | velingara
# Processing Record 42 of Set 10 | taree
# Processing Record 43 of Set 10 | hofn
# Processing Record 44 of Set 10 | jalu
# Processing Record 45 of Set 10 | split
# Processing Record 46 of Set 10 | butembo
# Processing Record 47 of Set 10 | manicore
# Processing Record 48 of Set 10 | lesozavodsk
# Processing Record 49 of Set 10 | dingle
# Processing Record 50 of Set 10 | kruisfontein
# Processing Record 1 of Set 11 | pontianak
# Processing Record 2 of Set 11 | lysyye gory
# Processing Record 3 of Set 11 | waingapu
# Processing Record 4 of Set 11 | nahan
# Processing Record 5 of Set 11 | pervomayskoye
# Processing Record 6 of Set 11 | kokoda
# Processing Record 7 of Set 11 | venosa
# Processing Record 8 of Set 11 | krivosheino
# Processing Record 9 of Set 11 | jeremoabo
# Processing Record 10 of Set 11 | asfi
# Processing Record 11 of Set 11 | bolshaya glushitsa
# Processing Record 12 of Set 11 | taltal
# Processing Record 13 of Set 11 | waddan
# Processing Record 14 of Set 11 | meulaboh
# Processing Record 15 of Set 11 | belen
# Processing Record 16 of Set 11 | bouna
# Processing Record 17 of Set 11 | nevesinje
# Processing Record 18 of Set 11 | cedeno
# Processing Record 19 of Set 11 | serenje
# Processing Record 20 of Set 11 | vredendal
# Processing Record 21 of Set 11 | verkhnyaya inta
# Processing Record 22 of Set 11 | baranoa
# Processing Record 23 of Set 11 | gampola
# Processing Record 24 of Set 11 | rosarito
# Processing Record 25 of Set 11 | sitka
# Processing Record 26 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 11 | voyinka
# Processing Record 28 of Set 11 | bandar
# Processing Record 29 of Set 11 | leh
# Processing Record 30 of Set 11 | san jose
# Processing Record 31 of Set 11 | kyzyl-suu
# Processing Record 32 of Set 11 | zaria
# Processing Record 33 of Set 11 | waipawa
# Processing Record 34 of Set 11 | prata
# Processing Record 35 of Set 11 | bontang
# Processing Record 36 of Set 11 | korla
# Processing Record 37 of Set 11 | robat karim
# Processing Record 38 of Set 11 | hualmay
# Processing Record 39 of Set 11 | port hedland
# Processing Record 40 of Set 11 | vardo
# Processing Record 41 of Set 11 | orodara
# Processing Record 42 of Set 11 | banikoara
# Processing Record 43 of Set 11 | fort frances
# Processing Record 44 of Set 11 | tahta
# Processing Record 45 of Set 11 | romny
# Processing Record 46 of Set 11 | mackay
# Processing Record 47 of Set 11 | astana
# Processing Record 48 of Set 11 | malayal
# Processing Record 49 of Set 11 | williamsport
# Processing Record 50 of Set 11 | la grande
# Processing Record 1 of Set 12 | firozpur
# Processing Record 2 of Set 12 | bone
# Processing Record 3 of Set 12 | havre-saint-pierre
# Processing Record 4 of Set 12 | bose
# Processing Record 5 of Set 12 | pangai
# Processing Record 6 of Set 12 | latung
# Processing Record 7 of Set 12 | boddam
# Processing Record 8 of Set 12 | zhigansk
# Processing Record 9 of Set 12 | pushkino
# Processing Record 10 of Set 12 | olafsvik
# Processing Record 11 of Set 12 | lumajang
# Processing Record 12 of Set 12 | strezhevoy
# Processing Record 13 of Set 12 | piacabucu
# Processing Record 14 of Set 12 | noumea
# Processing Record 15 of Set 12 | fairbanks
# Processing Record 16 of Set 12 | bandarban
# Processing Record 17 of Set 12 | khudumelapye
# Processing Record 18 of Set 12 | college
# Processing Record 19 of Set 12 | aguimes
# Processing Record 20 of Set 12 | kandrian
# Processing Record 21 of Set 12 | lakes entrance
# Processing Record 22 of Set 12 | alice
# Processing Record 23 of Set 12 | innisfail
# Processing Record 24 of Set 12 | kemi
# Processing Record 25 of Set 12 | massakory
# Processing Record 26 of Set 12 | fukue
# Processing Record 27 of Set 12 | steamboat springs
# Processing Record 28 of Set 12 | itaituba
# Processing Record 29 of Set 12 | cherepet
# Processing Record 30 of Set 12 | creel
# Processing Record 31 of Set 12 | krasnoselkup
# Processing Record 32 of Set 12 | baton rouge
# Processing Record 33 of Set 12 | bjornevatn
# Processing Record 34 of Set 12 | rybachiy
# Processing Record 35 of Set 12 | adrar
# Processing Record 36 of Set 12 | boyolangu
# Processing Record 37 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 12 | karratha
# Processing Record 39 of Set 12 | tyumentsevo
# Processing Record 40 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 12 | matongo
# Processing Record 42 of Set 12 | lappeenranta
# Processing Record 43 of Set 12 | pilar
# Processing Record 44 of Set 12 | amalapuram
# Processing Record 45 of Set 12 | burewala
# Processing Record 46 of Set 12 | sao filipe
# Processing Record 47 of Set 12 | khandyga
# Processing Record 48 of Set 12 | aransas pass
# Processing Record 49 of Set 12 | fomboni
# Processing Record 50 of Set 12 | sao jose da coroa grande
# Processing Record 1 of Set 13 | tacarigua
# Processing Record 2 of Set 13 | san clemente
# Processing Record 3 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 13 | vila franca do campo
# Processing Record 5 of Set 13 | maceio
# Processing Record 6 of Set 13 | belyy yar
# Processing Record 7 of Set 13 | champerico
# Processing Record 8 of Set 13 | kyabram
# Processing Record 9 of Set 13 | bonthe
# Processing Record 10 of Set 13 | emporia
# Processing Record 11 of Set 13 | najran
# Processing Record 12 of Set 13 | constitucion
# Processing Record 13 of Set 13 | broome
# Processing Record 14 of Set 13 | valparaiso
# Processing Record 15 of Set 13 | paamiut
# Processing Record 16 of Set 13 | pak phanang
# Processing Record 17 of Set 13 | fenoarivo
# Processing Record 18 of Set 13 | mlonggo
# Processing Record 19 of Set 13 | niquero
# Processing Record 20 of Set 13 | vidim
# Processing Record 21 of Set 13 | bethanien
# Processing Record 22 of Set 13 | pacifica
# Processing Record 23 of Set 13 | yamoussoukro
# Processing Record 24 of Set 13 | maragogi
# Processing Record 25 of Set 13 | qaqortoq
# ------------------
# Data Retrieval Complete
# ------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata = pd.DataFrame(citydatalist)

citydata.count()
# Out:
# City_ID       585
# City          585
# Cloudiness    585
# Country       585
# Date          585
# Humidity      585
# Lat           585
# Lng           585
# Max Temp      585
# Wind Speed    585
# dtype: int64

# %%
df = pd.read_csv (r'output_data/cities.csv')
print (df)

citydata_file = os.path.join('output_data/cities_1.csv')
df.to_csv(citydata_file)

citydata.head()
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]
#    City_ID            City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0          atuona          27      PF  1606560355        72  -9.80
# 1        1     yellowknife          75      CA  1606560356        76  62.46
# 2        3            hovd          43      MN  1606560356        93  48.01
# 3        4  ribeira grande          40      PT  1606560356        66  38.52
# 4        5  elizabeth city          90      US  1606560356       100  36.29
#
#       Lng  Max Temp  Wind Speed
# 0 -139.03     78.64       18.88
# 1 -114.35     -8.00        2.24
# 2   91.64     14.07        0.36
# 3  -28.70     55.40        6.93
# 4  -76.25     55.00        4.70

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Grab and format today's date for the graph titles
todaystring=str(pd.to_datetime(citydata.Date.mean(),unit='s'))
month=todaystring[5:7]
day=todaystring[8:10]
year=todaystring[0:4]
today=month+"/"+day+"/"+year

plt.scatter(citydata.Lat,citydata["Max Temp"],edgecolors="black")
plt.title(f"City Lat. vs Max Temperature ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Max Temperature (F)")
plt.grid(b=True,axis="both")

plt.savefig("output_data/CityLat_v_MaxTemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(citydata.Lat,citydata.Humidity,edgecolors="black")
plt.title(f"City Lat. vs Humidity ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Humidity (%)")
plt.grid(b=True,axis="both")

plt.savefig("output_data/CityLat_v_Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(citydata.Lat,citydata.Cloudiness,edgecolors="black")
plt.title(f"City Lat. vs Cloudiness ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Cloudiness (%)")
plt.grid(b=True,axis="both")

plt.savefig("output_data/CityLat_v_Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(citydata.Lat,citydata["Wind Speed"],edgecolors="black")
plt.title(f"City Lat. vs Wind Speed ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True,axis="both")

plt.savefig("output_data/CityLat_v_WindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %%
plt.scatter(citydata.Lat,citydata["Wind Speed"],edgecolors="black")
plt.title(f"City Lat. vs Wind Speed ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True,axis="both")

plt.savefig("output_data/CityLat_v_WindSpeed.png")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating Northern Hemisphere DataFrame
northerncitydata = df.loc[df["Lat"] >= 0]
northerncitydata
# Out:
#      City_ID               City  Cloudiness Country        Date  Humidity  \
# 0          0          ostrovnoy           2      RU  1558378754        72
# 2          2            qaanaaq          25      GL  1558378755        73
# 3          3             zhuhai           0      CN  1558378755        39
# 8          8              tiksi          95      RU  1558378756        88
# 9          9  pushkinskiye gory           6      RU  1558378756        70
# ..       ...                ...         ...     ...         ...       ...
# 543      543             yabrud           0      SY  1558378840        32
# 544      544            paraiso           5      MX  1558378898         4
# 545      545            veraval           0      FR  1558378898        62
# 546      546        novyy urgal         100      RU  1558378899        93
# 547      547            tongren           4      CN  1558378899        64
#
#        Lat     Lng  Max Temp  Wind Speed
# 0    68.05   39.51     37.50        7.16
# 2    77.48  -69.36     22.20        2.37
# 3    40.71  112.04     44.60        4.47
# 8    71.64  128.87     14.10       15.70
# 9    57.02   28.91     65.04        6.93
# ..     ...     ...       ...         ...
# 543  33.97   36.66     80.60        8.05
# 544  24.01 -104.61     84.20       16.11
# 545  49.65    0.71     61.00        8.05
# 546  51.07  132.56     49.74        2.68
# 547  27.72  109.18     55.86        2.84
#
# [380 rows x 10 columns]

# %%
#Use for reference - Northern Hemisphere DataFrame 
# northerncitydata = df.loc[df["Lat"] >= 0]
# northerncitydata

from scipy.stats import linregress

y = northerncitydata["Max Temp"]
x = northerncitydata["Lat"]
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
regression_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northerncitydata['Lat'],northerncitydata['Max Temp'],edgecolors='k')
plt.ylabel("Max Temperature (F)")
plt.plot(x, regression_values, "red")
plt.xlabel("Latitude (degrees)")
plt.title(f"Northern Hemisphere vs Max Temperature ({today})")
plt.grid()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2

plt.plot(x, regression_values,"r-")
plt.annotate((line_eq),(45,100),fontsize=15,color="red")

print(f"The r-squared is: {[rvalue]}")      

plt.savefig("output_data/NorthernCityLat_v_MaxTemp.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating Southern Hemisphere DataFrame
southerncitydata = df.loc[df["Lat"] >= 0]
southerncitydata
# Out:
#      City_ID               City  Cloudiness Country        Date  Humidity  \
# 0          0          ostrovnoy           2      RU  1558378754        72
# 2          2            qaanaaq          25      GL  1558378755        73
# 3          3             zhuhai           0      CN  1558378755        39
# 8          8              tiksi          95      RU  1558378756        88
# 9          9  pushkinskiye gory           6      RU  1558378756        70
# ..       ...                ...         ...     ...         ...       ...
# 543      543             yabrud           0      SY  1558378840        32
# 544      544            paraiso           5      MX  1558378898         4
# 545      545            veraval           0      FR  1558378898        62
# 546      546        novyy urgal         100      RU  1558378899        93
# 547      547            tongren           4      CN  1558378899        64
#
#        Lat     Lng  Max Temp  Wind Speed
# 0    68.05   39.51     37.50        7.16
# 2    77.48  -69.36     22.20        2.37
# 3    40.71  112.04     44.60        4.47
# 8    71.64  128.87     14.10       15.70
# 9    57.02   28.91     65.04        6.93
# ..     ...     ...       ...         ...
# 543  33.97   36.66     80.60        8.05
# 544  24.01 -104.61     84.20       16.11
# 545  49.65    0.71     61.00        8.05
# 546  51.07  132.56     49.74        2.68
# 547  27.72  109.18     55.86        2.84
#
# [380 rows x 10 columns]

# %%
#Use for reference - Southern Hemisphere DataFrame
# southerncitydata = df.loc[df["Lat"] >= 0]
# southerncitydata

y = southerncitydata["Max Temp"]
x = southerncitydata["Lat"]
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
regression_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southerncitydata['Lat'],southerncitydata['Max Temp'],edgecolors='k')
plt.ylabel("Max Temperature (F)")
plt.plot(x, regression_values, "red")
plt.xlabel("Latitude (degrees)")
plt.title(f"Southern Hemisphere vs Max Temperature ({today})")
plt.grid()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2

plt.plot(x, regression_values,"r-")
plt.annotate((line_eq),(40,100),fontsize=15,color="red")

print(f"The r-squared is: {[rvalue]}")      

plt.savefig("output_data/SouthernCityLat_v_MaxTemp.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northerncitydata.Lat
y = northerncitydata.Humidity

plt.scatter(northerncitydata['Lat'],northerncitydata['Humidity'],edgecolors='k')
plt.title(f"Northern Hemisphere vs Humidity ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Humidity (%)")
plt.grid(b=True,axis="both")

plt.plot(x, regression_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

print(f"The r-squared is: {[rvalue]}")       

plt.savefig("output_data/NorthernCityLat_v_Humidity.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southerncitydata.Lat
y = southerncitydata.Humidity

plt.scatter(southerncitydata['Lat'],southerncitydata['Humidity'],edgecolors='k')
plt.title(f"Southern Hemisphere vs Humidity ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Humidity (%)")
plt.grid(b=True,axis="both")

plt.plot(x, regression_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

print(f"The r-squared is: {[rvalue]}")       

plt.savefig("output_data/SouthernCityLat_v_Humidity.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northerncitydata.Lat
y = northerncitydata.Cloudiness

plt.scatter(northerncitydata['Lat'],northerncitydata['Cloudiness'],edgecolors='k')
plt.title(f"Northern Hemisphere vs Cloudiness ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Cloudiness (%)")
plt.grid(b=True,axis="both")

plt.plot(x, regression_values,"r-")
plt.annotate(line_eq,(-2,25),fontsize=12,color="red")

print(f"The r-squared is: {[rvalue]}")

plt.savefig("output_data/NorthernCityLat_v_Cloudiness.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southerncitydata.Lat
y = southerncitydata.Cloudiness

plt.scatter(southerncitydata['Lat'],southerncitydata['Cloudiness'],edgecolors='k')
plt.title(f"Southern Hemisphere. vs Cloudiness ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Cloudiness (%)")
plt.grid(b=True,axis="both")

plt.plot(x, regression_values,"r-")
plt.annotate(line_eq,(-2,25),fontsize=12,color="red")

print(f"The r-squared is: {[rvalue]}")

plt.savefig("output_data/SouthernCityLat_v_Cloudiness.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northerncitydata.Lat
y = northerncitydata["Wind Speed"]

plt.scatter(northerncitydata['Lat'],northerncitydata['Wind Speed'],edgecolors='k')
plt.title(f"Northern Hemisphere vs Wind Speed ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True,axis="both")

plt.plot(x, regression_values,"r-")
plt.annotate(line_eq,(-2,45),fontsize=15,color="red")

print(f"The r-squared is: {[rvalue]}")

plt.savefig("output_data/NorthernCityLat_v_WindSpeed.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southerncitydata.Lat
y = southerncitydata["Wind Speed"]

plt.scatter(southerncitydata['Lat'],southerncitydata['Wind Speed'],edgecolors='k')
plt.title(f"Southern Hemisphere vs Wind Speed ({today})")
plt.xlabel("Latitude (degrees)")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True,axis="both")

plt.plot(x, regression_values,"r-")
plt.annotate(line_eq,(-2,45),fontsize=15,color="red")

print(f"The r-squared is: {[rvalue]}")

plt.savefig("output_data/SouthernCityLat_v_WindSpeed.png")
# Out:
# The r-squared is: [-0.8151657406810829]

# %% [markdown]
# ### Analysis
#
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the northern hemisphere tends to be warmer this time of year than the southern hemisphere. This may be due to the tilt of the earth.
#
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
#
# * There is no strong relationship between latitude and wind speed. However, in northern hemisphere, there is a flurry of cities with over 20 mph of wind.
